# %% [markdown]
# <a href="https://colab.research.google.com/github/Julia-Wambua/CDAV-/blob/main/Week_1_practice_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# DAY 1 PRACTICAL WORK
print("Hello World")
# variables
# a variable is a placeholder for a specific value
name = "Julia"
age = 18
print(name)
print(age)
print(f"My name is {name} and I am {age} years old")

# checking variable types
print(type(name))
print(type(age))

# HANDS ON EXERCISE
name = "Julia"
age = 18
course = "Data Science"
favourite_food = "Pizza"
hobby = "swimming"

print(f"My name is {name}.")
print(f"I am {age} years old.")
print(f"I amm currently doing {course}.")
print(f"My favourite food is {favourite_food}.")
print(f"I love {hobby}.")

# HOMEWORK ASSIGNMENT
name = "Julia"
age = 18
favourite_food = "Pizza"
favourite_movie = "Harry Potter and the Sorcerer's Stone"
career_goal = "To become a Cardiolodist"
print(f"My name is {name}.")
print(f"I am {age} years old.")
print(f"My favourite food is {favourite_food}.")
print(f"My favourite movie is {favourite_movie}.")
print(f"My dream is to become a {career_goal}")
# Out:
# Hello World
# Julia
# 18
# My name is Julia and I am 18 years old
# <class 'str'>
# <class 'int'>
# My name is Julia.
# I am 18 years old.
# I amm currently doing Data Science.
# My favourite food is Pizza.
# I love swimming.
# My name is Julia.
# I am 18 years old.
# My favourite food is Pizza.
# My favourite movie is Harry Potter and the Sorcerer's Stone.
# My dream is to become a To become a Cardiolodist

# %%
# DAY 2 PRACTICAK WORK
# input()

name = input("Enter your name: ")
print(f"Hello {name}!")

name = input("Enter your name: ")
fave_food = input("Enter your favourite food: ")
fave_sport = input("Enter your favourite sport: ")
print(f"Hello {name}!")
print(f"You like {fave_food}.")
print(f"Your favourite sport is {fave_sport}.")

# CONVERTING DATA TYPES (TYPECASTING)
age = int(input("Enter your age: "))
print(type(age))
print(age)

#The int is necessary to convert the input from a string to an integer.
#the input function always outputs its data as a string by default.
#Hence typecasting is necessary in order to carry out arithmetic
#operations where the need arises

num_1 = 15
num_2 = 30
print(num_1 + num_2)
print(num_1 - num_2)
print(num_1 * num_2)
print(num_1 / num_2)
print(num_1 % num_2)
print(num_1 ** num_2)
print(num_1 // num_2)

# COMPARISON OPERATORS
# Simply give a True or False output
print(num_1 == num_2)
print(num_1 != num_2)
print(num_1 > num_2)
print(num_1 < num_2)
print(num_1 >= num_2)
print(num_1 <= num_2)
# Out:
# Enter your name: Julia
# Hello Julia!
# Enter your name: Mwende
# Enter your favourite food: Pizza
# Enter your favourite sport: Swimming
# Hello Mwende!
# You like Pizza.
# Your favourite sport is Swimming.
# Enter your age: 18
# <class 'int'>
# 18
# 45
# -15
# 450
# 0.5
# 15
# 191751059232884086668491363525390625
# 0
# False
# True
# False
# True
# False
# True

# %%
# DAY 3 PRACTICAL WORK
# Decision making in python(if, elif, else statements)

age = 37
if age >= 18:
  print("Adult")
  print("Eligible to vote")


age = int(input("Enter your age: "))
if age >= 18:
  print("Adult")
  print("Eligible to vote")
else:
  print("Minor")
  print("Not eligible to vote")


marks = int(input("Enter your marks: "))
if marks >= 50:
  print("Congratulations, you have passed!")
else:
  print("Failiyaaaa!!!")



# Password checker

correct = "python123"
user_pass = input("Enter your password: ")
if user_pass == correct:
  print("Password correct. Access granted")
else:
  print("Password incorrect! Please try again!")


# MULTIPLE STATEMENTS(elif)

grade = int(input("Enter your grade: "))
if grade >= 90:
  print("A")
elif grade >= 80:
  print("B")
elif grade >= 70:
  print("C")
elif grade >= 60:
  print("D")
elif grade >= 50:
  print("E")
else:
  print("F")
# Out:
# Adult
# Eligible to vote
# Enter your age: 16
# Minor
# Not eligible to vote
# Enter your marks: 55
# Congratulations, you have passed!
# Enter your password: python123
# Password correct. Access granted
# Enter your grade: 99
# A
