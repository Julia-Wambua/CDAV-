# %% [markdown]
# <a href="https://colab.research.google.com/github/Julia-Wambua/CDAV-/blob/main/CDAV_day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MORNING ACTIVITIES

# %%
#36,39 and 45 (python workbook)
# Number 36
letter = input("Enter a letter of the alphabet: ")
if letter == "a" or letter == "e" or letter == "i" or letter =="o" or letter =="u":
  print("The letter entered is a vowel")
elif letter == ("y"):
  print("The letter entered is sometimes a vowel and sometimes a consonant")
else:
  print("The letter entered is a consonant")
# Out:
# Enter a letter of the alphabet: c
# The letter entered is a consonant

# %%
# Number 39
sound_level = int(input("Enter the sound level in decibels: "))
if sound_level > 130 :
  print("The sound level entered is louder than a Jackhammer.")
elif sound_level == 130:
  print("THis corresponds to a Jackhammer.")
elif sound_level > 106 and sound_level < 130:
  print("This is found between a Jackhammer and a Gas Lawnmower")
elif sound_level == 106:
  print("This correesponds to a Gas Lawnmower")
elif sound_level > 70 and sound_level < 106:
  print("This is found between an Alarm Clock and a Gas Lawnmower")
elif sound_level == 70:
  print("This corresponds to an Alarm Clock")
elif sound_level > 40 and sound_level < 70:
  print("This is found between a Quiet Room and an Alarm Clock")
elif sound_level == 40:
  print("This corresponds to a Quiet Room")
elif sound_level < 40:
  print("The sound level entered is quieter than a Quiet Room")
# Out:
# Enter the sound level in decibels: 4
# The sound level entered is quieter than a Quiet Room

# %%
# Number 45
position = input("Enter a valid position on the chess board: ")
column = position[0].lower() # this is the letter e.g e1(e)

# the .lower() converts the column entered by the user from uppercase to
# lowercase
# in case they enter it in capital letters

row = int(position[1]) # this is the number e.g e1(1)


if column =="a" or column =="c" or column=="g" or column=="e":

  if row % 2 == 1:

    # if you divide 1 by 2, two goes into 1 zero times hecne leaving a
    # remainder of 1, thus 1 % 2 = 1, hence the code runs as it should

    print("The color of the square is black")
  else:
    print("The color of the square is white")

if column=="b" or column=="d" or column=="f" or column=="h":
  if row % 2 == 1:
    print("The color of the square is white")
  else:
    print("The color of the square is black")
# Out:
# Enter a valid position on the chess board: A1
# The color of the square is black

# %% [markdown]
# # While loop

# %%
# this is a simple program that prints hello world five times
counter = 5
# holds the number of times hello world will bw repeated(iterations)
while counter>0:
  print("Hello World")
  counter = counter - 1
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
counter = 0
while counter<5:
  print("Hello World")
  counter = counter + 1
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
counter = 1
while counter<=5:
  print("Hello World")
  counter = counter + 1
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
# Examples
stars = 3
while stars<=9:
  print("*"*stars)
  stars = stars + 3

  #or
#counter = 1
#while counter>=3:
  #print("***"*counter)
  #counter = counter + 1

# %%
password_incorrect = True
password = "Secret"

while password_incorrect:
  user_pass = input("Enter your password: ")
  if user_pass == password:
    print("Log in successful")
    password_incorrect = False  # control statement (guides the execution of your while loop)
  else:
    print("Incorrect password!!! Try again") # keeps looping until you enter the correct password
# Out:
# Enter your password: Julia
# Incorrect password!!! Try again
# Enter your password: fghjkl
# Incorrect password!!! Try again
# Enter your password: Secret
# Log in successful

# %% [markdown]
# write code that outputs
# ****************
#  **************
#   ************
#    **********
#     ********
#      ******
#       ****

# %%
stars = 16
spaces = 0
while stars>=4:
  print(" "*spaces + "*"*stars + " "*spaces)
  stars = stars - 2
  spaces = spaces + 1
# Out:
# ****************
#  **************
#   ************
#    **********
#     ********
#      ******
#       ****

# %%
# Question 61
not_entered_zero = True
items = 0
total = 0
while not_entered_zero:
  val = float(input("Enter a value: "))
  if val == 0:
    print(total/items)
    not_entered_zero = False
  else:
    total = total + val
    items = items + 1
# Out:
# Enter a value: 9
# Enter a value: 0
# 9.0

# %%
0
